# %%
# ------- Sorce Code Materi Responsi -------

# %%
# 2.Kepekatan Pelauang dengan Histogram  
 
from matplotlib import pyplot
from numpy.random import normal
# generate a sample
sample = normal(size=5000)
# plot a histogram of the sample
pyplot.hist(sample, bins=60)
pyplot.show()

# %%
# 3.Estimasi Kepekatan Parameterik 
# contoh parametric probability density estimation
# library yang digunakan 

from matplotlib import pyplot
from numpy.random import normal
from numpy import mean
from numpy import std
from scipy.stats import norm

# membangkitkan sample 
sample = normal(loc=50, scale=5, size=1000)

# menghitung parameters
sample_mean = mean(sample)
sample_std = std(sample)
print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean,
sample_std))

# mendefinisikan distribusi
dist = norm(sample_mean, sample_std)
values = [value for value in range(30, 70)]
probabilities = [dist.pdf(value) for value in values]

# plotting histogram and pdf
pyplot.hist(sample, bins=10, density=True)
pyplot.plot(values, probabilities)
pyplot.show()
# Out:
# Mean=49.756, Standard Deviation=4.995

# %%
# 4.Estimasi Kepekatan Nonparameterik

# Library yang diguanakan  
from matplotlib import pyplot
from numpy.random import normal
from numpy import hstack
from numpy import asarray
from numpy import exp
from sklearn.neighbors import KernelDensity

# Ilustrasi kondisi data bimodal dengan dua ditribusi yang berbeda

# contoh kondisi bimodal data
from matplotlib import pyplot
from numpy.random import normal
from numpy import hstack
# membangkitkan sample
sample1 = normal(loc=20, scale=5, size=300)
sample2 = normal(loc=40, scale=5, size=700)
sample = hstack((sample1, sample2))
# plot histogram
pyplot.hist(sample, bins=50)
pyplot.show()

# %%
# Untuk melakukan fitting terhadap sample tersebut, kita gunakan fungsi kernal density estimation 
 
model = KernelDensity(bandwidth=2, kernel='gaussian')
sample = sample.reshape((len(sample), 1))
model.fit(sample)
# Out:
# KernelDensity(bandwidth=2)

# %%
# Sebagai contoh yang digunakan adalah fungsi kepekatan kernal yang terdapa di dalam library
# scikit. Langkah berikutnya adalah menghitung peluang sample pada range tertentu 
 
# sample probabilities for a range of outcomes
values = asarray([value for value in range(1, 60)])
values = values.reshape((len(values), 1))
probabilities = model.score_samples(values)
probabilities = exp(probabilities)

# %%
# Setelah menentukan peluang sample tahap berikutya adalah melakukan plotting ke dalam kurva.  
# plot the histogram and pdf
pyplot.hist(sample, bins=50, density=True)
pyplot.plot(values[:], probabilities)
pyplot.show()

# %%
# ------- Sorce Code Tugas Responsi -------

# %%
# Tugas No.1
from matplotlib import pyplot
from numpy.random import normal

# Sample 1000 bin 20
sample = normal(size=1000)
# plot a histogram of the sample
pyplot.hist(sample, bins=20)
pyplot.show()

# Sample 3000 bin 40
sample = normal(size=3000)
# plot a histogram of the sample
pyplot.hist(sample, bins=40)
pyplot.show()

# Sample 5000 bin 60
sample = normal(size=5000)
# plot a histogram of the sample
pyplot.hist(sample, bins=60)
pyplot.show()

# %%
# Tugas No. 2
# DIstribusi Exponensial

from scipy.stats import expon
import seaborn as sns
from matplotlib import pyplot

data_expon = expon.rvs(scale=1,loc=0,size=1000)
ax = sns.distplot(data_expon, kde=True, bins=100, color='skyblue', hist_kws={"linewidth": 15,'alpha':1})
ax.set(xlabel='Exponential Distribution', ylabel='Frequency')

#pyplot.hist(data_expon, bins=100)
#pyplot.show()
# Out:
# c:\users\agung pambudi\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# [Text(0.5, 0, 'Exponential Distribution'), Text(0, 0.5, 'Frequency')]

# %%
# Tugas No.3
from matplotlib import pyplot
from numpy.random import normal
from numpy import hstack
from numpy import asarray
from numpy import exp
from sklearn.neighbors import KernelDensity

# membangkitkan 3 sample (multimodal) 
sample1 = normal(loc=20, scale=5, size=500)
sample2 = normal(loc=40, scale=5, size=800)
sample3 = normal(loc=60, scale=5, size=1000)

sample = hstack((sample1, sample2, sample3))
# plot histogram
pyplot.hist(sample, bins=50)
pyplot.show()

model = KernelDensity(bandwidth=2, kernel='gaussian')
sample = sample.reshape((len(sample), 1))
model.fit(sample)

# sample probabilities for a range of outcomes
values = asarray([value for value in range(1, 70)])
values = values.reshape((len(values), 1))
probabilities = model.score_samples(values)
probabilities = exp(probabilities)

# plot the histogram and pdf
pyplot.hist(sample, bins = 50, density=True)
pyplot.plot(values[:], probabilities)
pyplot.show()
